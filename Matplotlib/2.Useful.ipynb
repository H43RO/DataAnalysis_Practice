# %%
# 범주가 있는 그래프 그리기

import matplotlib.pyplot as plt

plt.plot([1,2,3], [1,4,9])
plt.plot([2,3,4], [5,6,7])
plt.xlabel("Sequence")
plt.ylabel("Time(secs)")
plt.title("Experiment Result")
plt.legend(["Mouse", "Cat"])
plt.show()

# %%
# 점 그래프 그리기

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-9, 10)
y = x ** 2
plt.plot(
    x, y,
    linestyle=":",
    marker="o",
    markersize=8,
    markerfacecolor="red",
    markeredgecolor="black"
)
plt.show()

# %%
# 막대 그래프 그리기

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-9, 10)
plt.bar(x, x ** 2)
plt.show()

# %%
# 누적 막대 그래프 그리기

import matplotlib.pyplot as plt
import numpy as np

# 0부터 1 사이의 값 10개 생성
x = np.random.rand(10)  # 아래 막대
y = np.random.rand(10)  # 중간 막대
z = np.random.rand(10)  # 위 막대
data = [x, y, z]
x_array = np.arange(10)
for i in range(0, 3):  # 누적 막대의 종류 3회 만큼 (돌아가면서)
    plt.bar(
        x_array,  # 0부터 10까지의 X 위치에서
        data[i],  # 각 높이 (10개) 만큼 쌓음
        bottom=np.sum(data[:i], axis=0)  # bottom (시작) 변경하여 누적 형태로 그림
    )
plt.show()

# %%
# 스캐터 그래프 그리기 (데이터 분산 및 분포 등에 사용)

import matplotlib.pyplot as plt
import numpy as np

# (x, y) 좌표를 가지는 0부터 1 사이의 값 총 10개의 데이터 생성
x = np.random.rand(10)
y = np.random.rand(10)
colors = np.random.randint(0, 100, 10)  # 랜덤 색깔
sizes = np.pi * 1000 * np.random.rand(10)  # 랜덤 크기 (공간)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.7)
plt.show()
