# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [1, 2, 3]
plt.plot(x, y)
plt.title("Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
plt.savefig('picture.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
